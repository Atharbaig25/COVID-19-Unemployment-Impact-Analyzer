# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv('Iris.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print("Dataset Information:")
print(f"Shape: {df.shape}")
print(f"\nColumn names: {df.columns.tolist()}")
print(f"\nMissing values:\n{df.isnull().sum()}")
# Out:
# Dataset Information:
# Shape: (150, 6)
#
# Column names: ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']
#
# Missing values:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
print("Species distribution:")
print(df['Species'].value_counts())
# Out:
# Species distribution:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
plt.figure(figsize=(12, 8))
sns.pairplot(df, hue='Species', palette='viridis')
plt.suptitle('Pairplot of Iris Features by Species', y=1.02)
plt.show()

# %%
plt.figure(figsize=(15, 10))
features = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

for i, feature in enumerate(features, 1):
    plt.subplot(2, 2, i)
    sns.boxplot(x='Species', y=feature, data=df, palette='Set2')
    plt.title(f'{feature} by Species')
    
plt.tight_layout()
plt.show()
# Out:
# C:\Users\N TECH\AppData\Local\Temp\ipykernel_14140\3395562478.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Species', y=feature, data=df, palette='Set2')
# C:\Users\N TECH\AppData\Local\Temp\ipykernel_14140\3395562478.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Species', y=feature, data=df, palette='Set2')
# C:\Users\N TECH\AppData\Local\Temp\ipykernel_14140\3395562478.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Species', y=feature, data=df, palette='Set2')
# C:\Users\N TECH\AppData\Local\Temp\ipykernel_14140\3395562478.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Species', y=feature, data=df, palette='Set2')

# %%
X = df.drop(['Id', 'Species'], axis=1)
y = df['Species']

le = LabelEncoder()
y_encoded = le.fit_transform(y)

print("Feature matrix shape:", X.shape)
print("Target variable shape:", y_encoded.shape)
print("Classes:", le.classes_)
# Out:
# Feature matrix shape: (150, 4)
# Target variable shape: (150,)
# Classes: ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y)

print("Training set shape:", X_train.shape)
print("Testing set shape:", X_test.shape)
# Out:
# Training set shape: (120, 4)
# Testing set shape: (30, 4)

# %%
model = RandomForestClassifier(random_state=42, n_estimators=100)
model.fit(X_train, y_train)

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
y_pred = model.predict(X_test)
y_pred_proba = model.predict_proba(X_test)

print("Predictions made on test data")
# Out:
# Predictions made on test data

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.4f} ({accuracy*100:.2f}%)")
# Out:
# Model Accuracy: 0.9000 (90.00%)

# %%
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.82      0.90      0.86        10
#  Iris-virginica       0.89      0.80      0.84        10
#
#        accuracy                           0.90        30
#       macro avg       0.90      0.90      0.90        30
#    weighted avg       0.90      0.90      0.90        30

# %%
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.82      0.90      0.86        10
#  Iris-virginica       0.89      0.80      0.84        10
#
#        accuracy                           0.90        30
#       macro avg       0.90      0.90      0.90        30
#    weighted avg       0.90      0.90      0.90        30

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
feature_importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': model.feature_importances_
}).sort_values('Importance', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance, palette='coolwarm')
plt.title('Feature Importance')
plt.show()

print("Feature Importance:")
print(feature_importance)
# Out:
# C:\Users\N TECH\AppData\Local\Temp\ipykernel_14140\3939694008.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=feature_importance, palette='coolwarm')
# Feature Importance:
#          Feature  Importance
# 3   PetalWidthCm    0.437185
# 2  PetalLengthCm    0.431466
# 0  SepalLengthCm    0.116349
# 1   SepalWidthCm    0.015000

# %%
sample_data = [
    [5.1, 3.5, 1.4, 0.2],  
    [6.0, 2.7, 5.1, 1.6],    
    [7.7, 3.0, 6.1, 2.3]   

sample_pred = model.predict(sample_data)
sample_pred_species = le.inverse_transform(sample_pred)

print("Sample Predictions:")
for i, (data, pred) in enumerate(zip(sample_data, sample_pred_species)):
    print(f"Sample {i+1}: {data} -> {pred}")
# Out:
# Sample Predictions:
# Sample 1: [5.1, 3.5, 1.4, 0.2] -> Iris-setosa
# Sample 2: [6.0, 2.7, 5.1, 1.6] -> Iris-versicolor
# Sample 3: [7.7, 3.0, 6.1, 2.3] -> Iris-virginica
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
print("="*50)
print("IRIS CLASSIFICATION PROJECT SUMMARY")
print("="*50)
print(f"📊 Dataset: {df.shape[0]} samples, {df.shape[1]} features")
print(f"🎯 Classes: {', '.join(df['Species'].unique())}")
print(f"🤖 Model: Random Forest Classifier")
print(f"✅ Accuracy: {accuracy:.4f} ({accuracy*100:.2f}%)")
print(f"📈 Most important feature: {feature_importance['Feature'].iloc[0]}")
print(f"🔮 Sample predictions all correct: {all(sample_pred_species == ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'])}")
# Out:
# ==================================================
# IRIS CLASSIFICATION PROJECT SUMMARY
# ==================================================
# 📊 Dataset: 150 samples, 6 features
# 🎯 Classes: Iris-setosa, Iris-versicolor, Iris-virginica
# 🤖 Model: Random Forest Classifier
# ✅ Accuracy: 0.9000 (90.00%)
# 📈 Most important feature: PetalWidthCm
# 🔮 Sample predictions all correct: True
